# %%
import pandas as pd
import numpy as np
import os

# %%
ranking_df=pd.read_csv("data/2021-05-29_game_id_rankings.csv")
ranking_df
# Out:
#       BoardGameRank  2018-10-06  2018-10-13  2018-10-20  2018-10-27  \
# 0                 1    174430.0    174430.0    174430.0    174430.0
# 1                 2    161936.0    161936.0    161936.0    161936.0
# 2                 3    182028.0    182028.0    182028.0    182028.0
# 3                 4    167791.0    167791.0    167791.0    167791.0
# 4                 5     12333.0     12333.0     12333.0     12333.0
# ...             ...         ...         ...         ...         ...
# 5009           5006         NaN         NaN         NaN         NaN
# 5010           5009         NaN         NaN         NaN         NaN
# 5011           5007         NaN         NaN         NaN         NaN
# 5012           5023         NaN         NaN         NaN         NaN
# 5013           5021         NaN         NaN         NaN         NaN
#
#       2018-11-03  2018-11-09  2018-11-17  2018-11-24  2018-12-01  ...  \
# 0       174430.0    174430.0    174430.0    174430.0    174430.0  ...
# 1       161936.0    161936.0    161936.0    161936.0    161936.0  ...
# 2       182028.0    182028.0    182028.0    182028.0    182028.0  ...
# 3       167791.0    167791.0    167791.0    167791.0    167791.0  ...
# 4        12333.0     12333.0     12333.0     12333.0     12333.0  ...
# ...          ...         ...         ...         ...         ...  ...
# 5009         NaN         NaN         NaN         NaN         NaN  ...
# 5010         NaN         NaN         NaN         NaN         NaN  ...
# 5011         NaN         NaN         NaN         NaN         NaN  ...
# 5012         NaN         NaN         NaN         NaN         NaN  ...
# 5013         NaN         NaN         NaN         NaN         NaN  ...
#
#       2021-03-20  2021-03-27  2021-04-03  2021-04-10  2021-04-17  2021-04-24  \
# 0       174430.0    174430.0    174430.0    174430.0    174430.0    174430.0
# 1       161936.0    161936.0    161936.0    161936.0    161936.0    161936.0
# 2       224517.0    224517.0    224517.0    224517.0    224517.0    224517.0
# 3       167791.0    167791.0    167791.0    167791.0    167791.0    167791.0
# 4       233078.0    233078.0    233078.0    233078.0    233078.0    233078.0
# ...          ...         ...         ...         ...         ...         ...
# 5009         NaN         NaN         NaN         NaN         NaN         NaN
# 5010         NaN         NaN         NaN         NaN         NaN         NaN
# 5011         NaN         NaN         NaN         NaN         NaN         NaN
# 5012         NaN         NaN         NaN         NaN         NaN         NaN
# 5013         NaN         NaN         NaN    253368.0         NaN         NaN
#
#       2021-05-01  2021-05-08  2021-05-15  2021-05-22
# 0       174430.0    174430.0    174430.0    174430.0
# 1       161936.0    161936.0    161936.0    161936.0
# 2       224517.0    224517.0    224517.0    224517.0
# 3       167791.0    167791.0    167791.0    167791.0
# 4       233078.0    233078.0    233078.0    233078.0
# ...          ...         ...         ...         ...
# 5009         NaN         NaN         NaN         NaN
# 5010         NaN         NaN         NaN         NaN
# 5011         NaN         NaN         NaN    161578.0
# 5012         NaN         NaN         NaN         NaN
# 5013         NaN         NaN         NaN         NaN
#
# [5014 rows x 139 columns]

# %%
game_info_df=pd.read_csv("data/boardgames2_06022021.csv")
print(game_info_df.columns)
game_info_df
# Out:
# Index(['objectid', 'name', 'yearpublished', 'sortindex', 'minplayers',
#        'maxplayers', 'minplaytime', 'maxplaytime', 'minage', 'min_community',
#        'max_community', 'totalvotes', 'playerage', 'languagedependence',
#        'usersrated', 'average', 'baverage', 'stddev', 'avgweight',
#        'numweights', 'numgeeklists', 'numtrading', 'numwanting', 'numcomments',
#        'siteviews', 'numplays', 'numplays_month', 'news', 'blogs', 'weblink',
#        'podcast', 'label', 'boardgamedesigner_cnt', 'boardgameartist_cnt',
#        'boardgamepublisher_cnt', 'boardgamehonor_cnt', 'boardgamecategory_cnt',
#        'boardgamemechanic_cnt', 'boardgameexpansion_cnt',
#        'boardgameversion_cnt', 'boardgamefamily_cnt', 'boardgamedesigner',
#        'boardgameartist', 'boardgamepublisher', 'boardgamehonor',
#        'boardgamecategory', 'boardgameversion', 'boardgamemechanic',
#        'boardgameexpansion', 'boardgamefamily', 'description', 'gamelink'],
#       dtype='object')
#        objectid                               name  yearpublished  sortindex  \
# 0        174430                         Gloomhaven           2017          1
# 1        161936          Pandemic Legacy  Season 1           2015          2
# 2        224517                  Brass  Birmingham           2018          3
# 3        167791                  Terraforming Mars           2016          4
# 4        233078  Twilight Imperium  Fourth Edition           2017          5
# ...         ...                                ...            ...        ...
# 19995     39662                           Cash Cab           2008      19996
# 19996     34390            Bakugan Battle Brawlers           2006      19997
# 19997      7314                       Mystery Date           1965      19998
# 19998     18736                         CSI  Miami           2005      19999
# 19999     15046   Monopoly  Star Wars Saga Edition           2005      20000
#
#        minplayers  maxplayers  minplaytime  maxplaytime  minage  \
# 0               1           4           60          120      14
# 1               2           4           60           60      13
# 2               2           4           60          120      14
# 3               1           5          120          120      12
# 4               3           6          240          480      14
# ...           ...         ...          ...          ...     ...
# 19995           2           4           30           45       0
# 19996           2           4           15           15       0
# 19997           2           4           30           30       7
# 19998           2           6           45           45      13
# 19999           2           8           60          120       8
#
#        min_community  ...                                    boardgameartist  \
# 0                3.0  ...  ['Alexandr Elichev', 'Josh T. McDowell', 'Alva...
# 1                4.0  ...                                ['Chris Quilliams']
# 2                3.0  ...  ['Lina Cossette', 'David Forest', 'Damien Mamm...
# 3                3.0  ...                                ['Isaac Fryxelius']
# 4                6.0  ...                                ['Scott Schomburg']
# ...              ...  ...                                                ...
# 19995            4.0  ...                                   ['(Uncredited)']
# 19996            NaN  ...                              ['Luke Peterschmidt']
# 19997            NaN  ...                   ['(Uncredited)', 'Marvin Glass']
# 19998            6.0  ...  ['Jeff Colthorpe', 'Ed Moitoso', 'Mark Sutclif...
# 19999            3.0  ...                                    ['Will Creech']
#
#                                       boardgamepublisher  \
# 0      ['Cephalofair Games', 'Albi', 'Albi Polska', '...
# 1      ['Z-Man Games', 'Asterion Press', 'Devir', 'Fi...
# 2      ['Roxley', 'Arclight', 'BoardM Factory', 'Conc...
# 3      ['FryxGames', 'Arclight', 'Bru00e4dspel.se', '...
# 4      ['Fantasy Flight Games', 'ADC Blackfire Entert...
# ...                                                  ...
# 19995                              ['Imagination Games']
# 19996                  ['Sega Toys', 'Spin Master Ltd.']
# 19997                       ['Hasbro', 'Milton Bradley']
# 19998  ['Jumbo', 'Piatnik', 'Specialty Board Games', ...
# 19999                      ['Hasbro', 'Parker Brothers']
#
#                                           boardgamehonor  \
# 0      ['2017 Best Science Fiction or Fantasy Board G...
# 1      ['2015 Board Game Quest Awards Best Coop Game ...
# 2      ['2018 Board Game Quest Awards Best Production...
# 3      ['2016 Board Game Quest Awards Best Strategy/E...
# 4      ['2017 Golden Geek Best Strategy Board Game No...
# ...                                                  ...
# 19995                                           ['None']
# 19996                                           ['None']
# 19997                                           ['None']
# 19998                                           ['None']
# 19999                                           ['None']
#
#                                        boardgamecategory  \
# 0      ['Adventure', 'Exploration', 'Fantasy', 'Fight...
# 1                           ['Environmental', 'Medical']
# 2      ['Economic', 'Industry / Manufacturing', 'Trai...
# 3      ['Economic', 'Environmental', 'Industry / Manu...
# 4      ['Civilization', 'Economic', 'Exploration', 'N...
# ...                                                  ...
# 19995            ['Movies / TV / Radio theme', 'Trivia']
# 19996  ['Action / Dexterity', 'Collectible Components...
# 19997  ['Childrens Game', 'Electronic', 'Movies / TV ...
# 19998                                      ['Deduction']
# 19999  ['Economic', 'Movies / TV / Radio theme', 'Neg...
#
#                                         boardgameversion  \
# 0      ['Chinese edition', 'Czech edition', 'English ...
# 1      ['Chinese blue edition', 'Chinese red edition'...
# 2      ['Chinese edition', 'Czech/English edition', '...
# 3      ['Bulgarian edition', 'Chinese edition', 'Czec...
# 4      ['Chinese edition', 'Czech edition', 'English ...
# ...                                                  ...
# 19995                                ['English edition']
# 19996  ['Area Majority / Influence', 'Hand Management...
# 19997  ['English edition', 'Hasbro Nostalgia edition'...
# 19998  ['Dutch edition', 'English edition', 'French e...
# 19999  ['Parker British edition', 'Parker Brothers ed...
#
#                                        boardgamemechanic  \
# 0      ['Action Queue', 'Action Retrieval', 'Campaign...
# 1      ['Action Points', 'Cooperative Game', 'Hand Ma...
# 2      ['Hand Management', 'Income', 'Loans', 'Market...
# 3      ['Drafting', 'End Game Bonuses', 'Hand Managem...
# 4      ['Action Drafting', 'Area Majority / Influence...
# ...                                                  ...
# 19995       ['Betting and Bluffing', 'Cooperative Game']
# 19996  ['Area Majority / Influence', 'Hand Management...
# 19997         ['Roll / Spin and Move', 'Set Collection']
# 19998                                      ['Deduction']
# 19999  ['Auction/Bidding', 'Player Elimination', 'Rol...
#
#                                       boardgameexpansion  \
# 0      ['Gloomhaven: Assault on the Morning Star (Pro...
# 1                                               ['None']
# 2                                               ['None']
# 3      ['French Championship Promo Cards (fan expansi...
# 4      ['Twilight Imperium: Fourth Edition u2013 Prop...
# ...                                                  ...
# 19995                                           ['None']
# 19996                                           ['None']
# 19997                                           ['None']
# 19998                        ['CSI: Miami Booster Pack']
# 19999                                           ['None']
#
#                                          boardgamefamily  \
# 0      ['Category: Dungeon Crawler', 'Components: Min...
# 1      ['Components: Map (Global Scale)', 'Game: Pand...
# 2      ['Cities: Birmingham (England)', 'Country: Eng...
# 3      ['Components: Map (Global Scale)', 'Components...
# 4      ['Components: Hexagonal Tiles', 'Components: M...
# ...                                                  ...
# 19995                        ['TV Shows: TV Game Shows']
# 19996  ['Collectible: Collectible Miniatures Games', ...
# 19997  ['Brands: Disney', 'Movies: High School Musical']
# 19998  ['Theme: Police', 'Theme: TV Detectives', 'TV ...
# 19999  ['Admin: Better Description Needed!', 'Game: M...
#
#                                              description  \
# 0      Vanquish monsters with strategic cardplay. Ful...
# 1      Mutating diseases are spreading around the wor...
# 2      Build networks, grow industries, and navigate ...
# 3      Compete with rival CEOs to make Mars habitable...
# 4      Build an intergalactic empire through trade, r...
# ...                                                  ...
# 19995  Cash Cab is a loose adaptation of a television...
# 19996  A hybrid of CCG, Marbles and Transforming Robo...
# 19997  Will you be dressed appropriately when it's ti...
# 19998  FEEL THE HEAT OF MIAMI!  Behind the sun, surf ...
# 19999  Experience classic Monopoly game play in the i...
#
#                                                 gamelink
# 0                           /boardgame/174430/gloomhaven
# 1             /boardgame/161936/pandemic-legacy-season-1
# 2                     /boardgame/224517/brass-birmingham
# 3                    /boardgame/167791/terraforming-mars
# 4      /boardgame/233078/twilight-imperium-fourth-edi...
# ...                                                  ...
# 19995                          /boardgame/39662/cash-cab
# 19996           /boardgame/34390/bakugan-battle-brawlers
# 19997                       /boardgame/7314/mystery-date
# 19998                         /boardgame/18736/csi-miami
# 19999   /boardgame/15046/monopoly-star-wars-saga-edition
#
# [20000 rows x 52 columns]

# %% [raw]
# objectid - the identifier on boardgamegeeks.com
# name - name of the game
# yearpublished - the year the game was published
# ortindex - rank of the game on bbg.com
# minplayer - minumum number of players per the publishers
# maxplayers - maximum number of players per the publishers
# minplaytime - minimum playtime required per the publishers
# maxplaytime - maximum playtime per the publishers
# minage - minimum age requiremnet per the publishers
# min_community - minimum players per the community
# max_community - max players per the community
# totalvotes - total number of community vote
# layerage - minimum age requirement per the community
# languagedependence - a rank of amount of in-game text is required during game play
# 1: none, 5: unplayable in other language
# serrated - number of users that have rated the game
# average - user average rating from 1-10
# average - from the site, determined to be an anti-skewing effort by bgg
# with system added mid range ratings (from 1-10)
# stddev - average standard deviation of a rating
# avgweight - a complexity rating from 1-5 Weight
# numweights - number of weight votes
# numgeeklists - number of geeks with game on list
# numtrading - number of people trading the game
# numwanting - number of people wanting the game
# numcomments - number of comments on the site on this game
# iteviews - number of views on the site
# numplays - number of times game was played (according to site users?)
# numplays_month - number of plays per month
# news - number news articles on game
# logs - number of blogs regarding game
# weblink - number of weblinks for the game
# podcast - number of podcasts on the game
# label - category of game (mostly boardgame)
# boardgamedesigner_cnt - count of designers
# boardgameartist_cnt - artist count
# boardgamepublisher_cnt - publisher count
# boardgamehonor_cnt - awards count
# boardgamecategory_cnt - category count
# boardgamemechanic_cnt - game mechanics count
# boardgameexpansion_cnt - expansion count
# boardgameversion_cnt - version count (languages)
# boardgamefamily_cnt - game family count
# boardgamedesigner - list of game designers
# boardgameartist - list of game artists
# boardgamepublisher - list of publishers
# boardgamehonor - list of awards
# boardgamecategory - list of categories
# boardgameversion - list of versions
# boardgamemechanic - a list of mechanics
# boardgameexpansion - a list of expansions
# boardgamefamily - a list of boardgames family
# description - full text description of game
# gamelink - a link to the game on bgg
